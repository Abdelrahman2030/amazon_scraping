# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import random

# %%
url = "https://www.noon.com/egypt-en/"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
content = response.content

# %%
soup = BeautifulSoup(content)

# %%
soup
# Out:
# <!-- tangram:5542 begin--><!-- tangram:6399 begin--><!DOCTYPE html>
# <html class="rwd" dir="ltr" lang="en">
# <head>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!--dns预解析建联-->
# <link crossorigin="" href="https://s.alicdn.com/" rel="preconnect"/>
# <link href="https://s.alicdn.com/" rel="dns-prefetch"/>
# <link href="//i.alicdn.com" rel="dns-prefetch"/>
# <link href="//is.alicdn.com" rel="dns-prefetch"/>
# <link href="//at.alicdn.com" rel="dns-prefetch"/>
# <link href="//u.alicdn.com" rel="dns-prefetch"/>
# <link href="//g.alicdn.com" rel="dns-prefetch"/>
# <link href="//sc01.alicdn.com" rel="dns-prefetch"/>
# <link href="//sc02.alicdn.com" rel="dns-prefetch"/>
# <link href="//gj.mmstat.com" rel="dns-prefetch"/>
# <link href="//gm.mmstat.com" rel="dns-prefetch"/>
# <link href="//assets.alicdn.com" rel="dns-prefetch"/>
# ...

# %%
soup.find("title")
# Out:
# <title>Spring And Summer Heavy Wash To Do Old Solid Color T-shirt Hip Hop Fashion Brand Japanese Casual Men's Short-sleeved T-shirt - Buy Heavy Wash To Make Old Solid Colored T-shirts,Casual Men's Short-sleeved T-shirt,Hip Hop Day T-shirt With Short Sleeves Product on Alibaba.com</title>

# %%
soup.find("span", class_ = "promotion").text
# Out:
# '$7.50'
