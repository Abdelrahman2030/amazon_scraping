# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import random

# %%
import time

# %%
pd.set_option("display.max_rows", 10)

# %% [markdown]
# ## Connecting to the website
# > **In this code i will connect to sutra**

# %%
user_agents_df = pd.read_csv("user_agents_list.csv")

# %%
keyword = input()
# Out:
# white

# %%
keyword = keyword.replace(" ", "+")

# %%
keyword
# Out:
# 'white'

# %%
sutra_url = "https://sutrastores.com/en/search?type=product&options%5Bunavailable_products%5D=hide&options%5Bprefix%5D=last&q={}".format(keyword)

# %%
sutra_url
# Out:
# 'https://sutrastores.com/en/search?type=product&options%5Bunavailable_products%5D=hide&options%5Bprefix%5D=last&q=black+shoes'

# %% [markdown]
# **This url is for the search result, after using this notebook i will write the code in suplime usinf functions, etc**

# %%
def response(url):
    #This function creates the request and it takes the url as input and returns the soup
    
    user_agent = random.choice(user_agents_df["user_agent"]) #Fake user agent
    
    headers = {"User-Agent": user_agent,
           "Accept-Encoding":"gzip, deflate",
           "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
           "DNT":"1","Connection":"close",
           "Upgrade-Insecure-Requests":"1",
          "Accept-Language": "en-US,en;q=0.9"}
    
    response = requests.get(url, headers = headers) # the request is made here
    content = response.content
    
    soup = BeautifulSoup(content, "html.parser")
    
    print(response)
    print(soup.find("title"))
    return soup

# %%
soup = response(sutra_url)
# Out:
# <Response [200]>
# <title>Search results: 4 Search Results for: “black shoes” – SUTRA</title>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="t4sp-theme t4s-wrapper__custom rtl_false swatch_color_style_2 pr_border_style_1 pr_img_effect_2 enable_eff_img1_true badge_shape_1 css_for_wis_app_true t4s-lzcus-true shadow_round_img_false t4s-header__categories is-remove-unavai-2 t4_compare_false is-catalog__mode-false t4s-sidebar-qv t4s-cart-count-0 t4s-pr-ellipsis-true no-js" lang="en">
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-5G5M7RD');</script>
# <!-- End Google Tag Manager -->
# <script crossorigin="anonymous" referrerpolicy="no-referrer" src="https://cdn.ecomposer.app/vendors/js/jquery.min.js"></script><script>
# ...

# %%
for index in range(2, 2 + 1):
    print(index)
# Out:
# 2

# %% [markdown]
# **unc statnds for unclean**

# %%
unc_titles_list = soup.find_all("h3", class_ = "t4s-product-title")
unc_titles_list
# This find gives us all the product titles in first page

# %%
titles_list = []
for index in unc_titles_list:
    titles_list.append(index.text)
    # This for loop exctracts the product names
    
print("The length of the list is : {}".format(len(titles_list)))

# %%
titles_list

# %%
unc_prices = soup.find_all("div", class_ = "t4s-product-price")
unc_prices

# %%
unc_prices[0].contents[1].text

# %%
old_prices_list = []
new_prices_list = []
discount_list = []

for index in unc_prices:
    old_price = index.contents[0].text
    old_price = float(old_price.split(" ")[1]) #This will reomve the LE from the price
    old_prices_list.append(old_price)
    
    new_price = index.contents[1].text
    new_price = float(new_price.split(" ")[1]) #This will reomve the LE from the price
    new_prices_list.append(new_price)
    
    discount = round(((old_price - new_price) / old_price) * 100)
    discount_list.append(discount)
    
print("The length is : {} old and {} new".format(len(old_prices_list), len(new_prices_list)))

# %%
discount_list

# %% [markdown]
# **Now I have all the desired results i will now find all the rsults in all pages**

# %%
soup.find_all("a", class_ = "t4s-pagination__item link")[-1].contents[0]
#This code will give me the max number of pages

# %% [markdown]
# **Now i will make a compinded function to exctract all the reults from sutra**

# %%
def sutra(soup):
    '''
    This function takes the parameter soup then gives me all the desired results 
    from sutra
    '''

    #The next section is for the titles
    unc_titles_list = soup.find_all("h3", class_ = "t4s-product-title")
    
    for index in unc_titles_list:
        titles_list.append(index.text)
        # This for loop exctracts the product names
    
    
    #The next section is for prices
    unc_prices = soup.find_all("div", class_ = "t4s-product-price")
    
    for index in unc_prices:
        old_price = index.contents[0].text
        old_price = float(old_price.split(" ")[1]) #This will reomve the LE from the price
        old_prices_list.append(old_price)
        
        try:
            new_price = index.contents[1].text
            new_price = float(new_price.split(" ")[1]) #This will reomve the LE from the price
            new_prices_list.append(new_price)
        except:
            new_price = old_price
            new_prices_list.append(new_price)

        discount = round(((old_price - new_price) / old_price) * 100)
        discount_list.append(discount)
        
        sources_list.append("sutra") #This will help us later when we merge datasets, to know wich market this came from

# %%
import time
start = time.time()

response = requests.get(sutra_url) # the request is made here
main_soup = BeautifulSoup(response.content)

end - time.time()
total = end - start
print(total)

# %%
import time
start = time.time()

main_soup = response(sutra_url) #The main soup is the soup of page one

end - time.time()
total = end - start
print(total)

# %%
main_soup.find_all("a", class_ = "t4s-pagination__item link")
# Out:
# [<a aria-label="Page 2" class="t4s-pagination__item link" href="/en/search?options%5Bprefix%5D=last&amp;options%5Bunavailable_products%5D=hide&amp;page=2&amp;q=white&amp;type=product">2</a>,
#  <a aria-label="Page 3" class="t4s-pagination__item link" href="/en/search?options%5Bprefix%5D=last&amp;options%5Bunavailable_products%5D=hide&amp;page=3&amp;q=white&amp;type=product">3</a>,
#  <a aria-label="Page 7" class="t4s-pagination__item link" href="/en/search?options%5Bprefix%5D=last&amp;options%5Bunavailable_products%5D=hide&amp;page=7&amp;q=white&amp;type=product">7</a>]

# %%
int(main_soup.find_all("a", class_ = "t4s-pagination__item link")[-1].contents[0])

# %%
# now i will make this function works for all of the pages
main_soup = response(sutra_url) #The main soup is the soup of page one
number_of_pages = int(main_soup.find_all("a", class_ = "t4s-pagination__item link")[-1].contents[0])

titles_list = []
old_prices_list = []
new_prices_list = []
discount_list = []
sources_list = []

for index in range(2, number_of_pages + 1):
    #This loop will repeate the response and sutra function for all pages
    
    next_page_url = sutra_url + "&page={}".format(index) #This will create the link
    
    soup = response(next_page_url) #creates the soup
    
    sutra(soup) #To exctract the values
    
    
    print("Page: {}".format(index))

# %%
len(discount_list)

# %%
len(titles_list)

# %%
# This code will create the final data frame
sutra_dict = {"product_name" : titles_list,
             "old_price" : old_prices_list,
             "new_price" : new_prices_list,
             "discount" : discount_list,
             "source" : sources_list}

sutra_df = pd.DataFrame(sutra_dict)

# %%
sutra_df

# %% [markdown]
# **I Have finished sutra**
